# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Bank Marketing.csv")

# %%
df.head()
# Out:
#    id  V1            V2       V3         V4  V5    V6   V7   V8       V9  V10  \
# 0   1  58    management  married   tertiary  no  2143  yes   no  unknown    5
# 1   2  44    technician   single  secondary  no    29  yes   no  unknown    5
# 2   3  33  entrepreneur  married  secondary  no     2  yes  yes  unknown    5
# 3   4  47   blue-collar  married    unknown  no  1506  yes   no  unknown    5
# 4   5  33       unknown   single    unknown  no     1   no   no  unknown    5
#
#    V11  V12  V13  V14  V15      V16  Class
# 0  may  261    1   -1    0  unknown      1
# 1  may  151    1   -1    0  unknown      1
# 2  may   76    1   -1    0  unknown      1
# 3  may   92    1   -1    0  unknown      1
# 4  may  198    1   -1    0  unknown      1

# %%
df.shape
# Out:
# (45211, 18)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=45211, step=1)

# %%
df.isnull().sum()
# Out:
# id       0
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# Class    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      45211 non-null  int64
#  1   V1      45211 non-null  int64
#  2   V2      45211 non-null  object
#  3   V3      45211 non-null  object
#  4   V4      45211 non-null  object
#  5   V5      45211 non-null  object
#  6   V6      45211 non-null  int64
#  7   V7      45211 non-null  object
#  8   V8      45211 non-null  object
#  9   V9      45211 non-null  object
#  10  V10     45211 non-null  int64
#  11  V11     45211 non-null  object
#  12  V12     45211 non-null  int64
#  13  V13     45211 non-null  int64
#  14  V14     45211 non-null  int64
#  15  V15     45211 non-null  int64
#  16  V16     45211 non-null  object
#  17  Class   45211 non-null  int64
# dtypes: int64(9), object(9)
# memory usage: 6.2+ MB

# %%
df.dtypes
# Out:
# id        int64
# V1        int64
# V2       object
# V3       object
# V4       object
# V5       object
# V6        int64
# V7       object
# V8       object
# V9       object
# V10       int64
# V11      object
# V12       int64
# V13       int64
# V14       int64
# V15       int64
# V16      object
# Class     int64
# dtype: object

# %%
df.describe()
# Out:
#                  id            V1             V6           V10           V12  \
# count  45211.000000  45211.000000   45211.000000  45211.000000  45211.000000
# mean   22606.000000     40.936210    1362.272058     15.806419    258.163080
# std    13051.435847     10.618762    3044.765829      8.322476    257.527812
# min        1.000000     18.000000   -8019.000000      1.000000      0.000000
# 25%    11303.500000     33.000000      72.000000      8.000000    103.000000
# 50%    22606.000000     39.000000     448.000000     16.000000    180.000000
# 75%    33908.500000     48.000000    1428.000000     21.000000    319.000000
# max    45211.000000     95.000000  102127.000000     31.000000   4918.000000
#
#                 V13           V14           V15         Class
# count  45211.000000  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323      1.116985
# std        3.098021    100.128746      2.303441      0.321406
# ...

# %%
df.corr()
# Out:
#              id        V1        V6       V10       V12       V13       V14  \
# id     1.000000  0.014973  0.073639 -0.061465  0.013031 -0.102884  0.437729
# V1     0.014973  1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758
# V6     0.073639  0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435
# V10   -0.061465 -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044
# V12    0.013031 -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565
# V13   -0.102884  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628
# V14    0.437729 -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000
# V15    0.271098  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820
# Class  0.296287  0.025155  0.052838 -0.028348  0.394521 -0.073172  0.103621
#
#             V15     Class
# id     0.271098  0.296287
# V1     0.001288  0.025155
# V6     0.016674  0.052838
# V10   -0.051710 -0.028348
# V12    0.001203  0.394521
# V13   -0.032855 -0.073172
# ...

# %%
for col in df.columns:
    print(f"the name of the {col}")
    print(df[col].value_counts())
    print(10*"***")
# Out:
# the name of the id
# 1        1
# 30200    1
# 30136    1
# 30137    1
# 30138    1
#         ..
# 15073    1
# 15074    1
# 15075    1
# 15076    1
# 45211    1
# Name: id, Length: 45211, dtype: int64
# ******************************
# the name of the V1
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 93       2
# 90       2
# 95       2
# 88       2
# 94       1
# Name: V1, Length: 77, dtype: int64
# ******************************
# the name of the V2
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: V2, dtype: int64
# ******************************
# the name of the V3
# married     27214
# single      12790
# divorced     5207
# Name: V3, dtype: int64
# ******************************
# the name of the V4
# ...

# %%
for cols in df.columns:
    print(f"the Column name is {col}")
    #print("***"*10)
    print(df[col].unique())
    print("***"*10)
# Out:
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ******************************
# the Column name is Class
# [1 2]
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Matrix", fontsize=20)
plt.show()

# %%
for col in df.columns:
    plt.figure(figsize =(15,5))
    sns.histplot(df[col], bins=30)
    plt.title(f"The Distrubution of {col}",fontsize=20)
    plt.xlabel(f"{col}", fontsize=10)
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(15, 5))
    sns.histplot(df[col], bins=30, kde=True)  # Use sns.histplot() instead of sns.boxplot()
    plt.title(f"The Distribution of {col}", fontsize=20)
    plt.xlabel(f"{col}", fontsize=10)
    plt.show()

# %%
sns.pairplot(df);

# %%
df.head(2)
# Out:
#    id  V1          V2       V3         V4  V5    V6   V7  V8       V9  V10  \
# 0   1  58  management  married   tertiary  no  2143  yes  no  unknown    5
# 1   2  44  technician   single  secondary  no    29  yes  no  unknown    5
#
#    V11  V12  V13  V14  V15      V16  Class
# 0  may  261    1   -1    0  unknown      1
# 1  may  151    1   -1    0  unknown      1

# %%
df.tail(2)
# Out:
#           id  V1            V2       V3         V4  V5    V6  V7  V8  \
# 45209  45210  57   blue-collar  married  secondary  no   668  no  no
# 45210  45211  37  entrepreneur  married  secondary  no  2971  no  no
#
#               V9  V10  V11  V12  V13  V14  V15      V16  Class
# 45209  telephone   17  nov  508    4   -1    0  unknown      1
# 45210   cellular   17  nov  361    2  188   11    other      1

# %%
df.drop(columns="id",axis=1,inplace=True)
df.head(2)
# Out:
#    V1          V2       V3         V4  V5    V6   V7  V8       V9  V10  V11  \
# 0  58  management  married   tertiary  no  2143  yes  no  unknown    5  may
# 1  44  technician   single  secondary  no    29  yes  no  unknown    5  may
#
#    V12  V13  V14  V15      V16  Class
# 0  261    1   -1    0  unknown      1
# 1  151    1   -1    0  unknown      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      45211 non-null  int64
#  1   V2      45211 non-null  object
#  2   V3      45211 non-null  object
#  3   V4      45211 non-null  object
#  4   V5      45211 non-null  object
#  5   V6      45211 non-null  int64
#  6   V7      45211 non-null  object
#  7   V8      45211 non-null  object
#  8   V9      45211 non-null  object
#  9   V10     45211 non-null  int64
#  10  V11     45211 non-null  object
#  11  V12     45211 non-null  int64
#  12  V13     45211 non-null  int64
#  13  V14     45211 non-null  int64
#  14  V15     45211 non-null  int64
#  15  V16     45211 non-null  object
#  16  Class   45211 non-null  int64
# dtypes: int64(8), object(9)
# memory usage: 5.9+ MB

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for column in df.select_dtypes(include='object'):
    df[column] = le.fit_transform(df[column])

# %%
df.head(5)
# Out:
#    V1  V2  V3  V4  V5    V6  V7  V8  V9  V10  V11  V12  V13  V14  V15  V16  \
# 0  58   4   1   2   0  2143   1   0   2    5    8  261    1   -1    0    3
# 1  44   9   2   1   0    29   1   0   2    5    8  151    1   -1    0    3
# 2  33   2   1   1   0     2   1   1   2    5    8   76    1   -1    0    3
# 3  47   1   1   3   0  1506   1   0   2    5    8   92    1   -1    0    3
# 4  33  11   2   3   0     1   0   0   2    5    8  198    1   -1    0    3
#
#    Class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
x = df.drop(columns="Class",axis=1)
y = df[["Class"]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.3, random_state=0)

# %%
data = {
    'x_train': x_train,
    'x_test': x_test,
    'y_train': y_train,
    'y_test': y_test
}

for key, value in data.items():
    print(f"{key}: {value.shape}")
# Out:
# x_train: (13563, 16)
# x_test: (31648, 16)
# y_train: (13563, 1)
# y_test: (31648, 1)

# %%
#ANN CLASSIFICATION
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
#input to model
model.add(Dense(16,activation="relu"))
#adding hidden layers
model.add(Dense(36,activation="relu"))
model.add(Dense(16,activation="relu"))
#output layer to the model
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=50,batch_size=20,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 679/679 [==============================] - 2s 2ms/step - loss: -139172.0000 - accuracy: 0.8780 - val_loss: -675008.7500 - val_accuracy: 0.8840
# Epoch 2/50
# 679/679 [==============================] - 1s 2ms/step - loss: -5469457.0000 - accuracy: 0.8806 - val_loss: -12711686.0000 - val_accuracy: 0.8840
# Epoch 3/50
# 679/679 [==============================] - 1s 2ms/step - loss: -38087120.0000 - accuracy: 0.8806 - val_loss: -60782116.0000 - val_accuracy: 0.8840
# Epoch 4/50
# 679/679 [==============================] - 1s 2ms/step - loss: -122327712.0000 - accuracy: 0.8806 - val_loss: -161699040.0000 - val_accuracy: 0.8840
# Epoch 5/50
# 679/679 [==============================] - 1s 2ms/step - loss: -283239328.0000 - accuracy: 0.8806 - val_loss: -339161856.0000 - val_accuracy: 0.8840
# Epoch 6/50
# 679/679 [==============================] - 1s 2ms/step - loss: -542111616.0000 - accuracy: 0.8806 - val_loss: -610411776.0000 - val_accuracy: 0.8840
# Epoch 7/50
# ...

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
####### Navie Byes #####
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

nav_model = GaussianNB()
nav_model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred3 = nav_model.predict(x_test)

# %%
acc_3 = accuracy_score(y_test, y_pred)
print("Accuracy:", acc_3)
# Out:
# Accuracy: 0.8840369059656218

# %%
####### DECISION_TREE #####
from sklearn.tree import DecisionTreeClassifier
dec_model = DecisionTreeClassifier()
dec_model.fit(x_train, y_train)
y_pred4 = dec_model.predict(x_test)
acc_4 = accuracy_score(y_test, y_pred)
print("Accuracy:", acc_4)
# Out:
# Accuracy: 0.8840369059656218

# %%
##### SVM ######
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(x_train,y_train)
y_pred5 = svm_model.predict(x_test)
acc5=accuracy_score(y_test,y_pred)
print("Acc: ", acc5)
# Out:
# Acc:  0.8840369059656218

# %%
##### ADA BOOST CLASSIFIER #####
from sklearn.ensemble import AdaBoostClassifier
adboost = AdaBoostClassifier(n_estimators=50, learning_rate=1)
adboost_model = adboost.fit(x_train, y_train)  # Use the 'fit' method to train the model
y_pred6 = adboost_model.predict(x_test)
acc_5 = accuracy_score(y_test, y_pred6)
print("Acc: ", acc_5)
# Out:
# Acc:  0.8979398382204247

# %%
###### RANDOM FOREST #####
from sklearn.ensemble import RandomForestClassifier
random_model = RandomForestClassifier()
random_model.fit(x_train, y_train)
y_pred7 = random_model.predict(x_test)  # Use the 'predict' method to make predictions
acc_6 = accuracy_score(y_test, y_pred7)
print("Acc: ", acc_6)
# Out:
# Acc:  0.903090242669363
